# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
# import
from scipy_pilutil import imread, imresize
import imageio
from skimage.transform import resize, rescale
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/train.csv').readlines())
# val_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/val.csv').readlines())
# batch_size = #experiment with the batch size

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('../Project_data/', ablation=None)
# train_doc, val_doc = get_data('/content/drive/MyDrive/gesture-recognition/Project_data/', ablation=None)

batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
image1 = imageio.imread("../Project_data/val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00015.png")
#160 by 120
image2 = imageio.imread("../Project_data/val/WIN_20180907_15_38_42_Pro_Thumbs Up_new/WIN_20180907_15_38_42_Pro_00007.png")
#crop the images and resize them. Note that the images are of 2 different shape
#and the conv3D will throw error if the inputs in a batch have different shapes
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)
plt.imshow(image2)
plt.show()
## Test code end

# %%
def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                    #batch_data[folder,idx,:,:,0] = (image[...,0] - image[...,0].min())/(image[...,0].max() - image[...,0].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,1] = (image[...,1] - image[...,1].min())/(image[...,1].max() - image[...,1].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,2] = (image[...,2] - image[...,2].min())/(image[...,2].max() - image[...,2].min())#normalise and feed in the image

                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
# train_path = '../Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
# val_path =  '../Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'
train_path = '../Project_data/train'
val_path =  '../Project_data/val'
#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
def convlstm2D(input_shape):
    model = Sequential()
    model.add(TimeDistributed(
        Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
    )
    model.add(BatchNormalization())
    model.add(TimeDistributed(
        Conv2D(16, (3,3), activation='relu'))
    )
    model.add(BatchNormalization())
    model.add(
        ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
    )
    model.add(BatchNormalization())
    model.add(TimeDistributed(
        Dense(64, activation='relu'))
    )
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling2D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(5, activation='softmax'))
    return model

model = convlstm2D(input_shape)

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generate(train_path, train_doc, batch_size)
val_generator = generate(val_path, val_doc, batch_size)

# %%
optimiser = optimizers.Adam(learning_rate=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 10, 118, 118,   │           224 │
# │ (TimeDistributed)               │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 10, 118, 118,   │            32 │
# │ (BatchNormalization)            │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 10, 116, 116,   │         1,168 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 10, 116, 116,   │            64 │
# │ (BatchNormalization)            │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 114, 114, 8)    │         6,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 114, 114, 8)    │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 114, 114, 64)   │           576 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 114, 114, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,781 (53.83 KB)
#  Trainable params: 13,589 (53.08 KB)
#  Non-trainable params: 192 (768.00 B)
# None

# %%
model_name = 'model_new_generator1' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_weights_only=False, save_best_only=False, mode='max')
LR =ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.3668 - loss: 1.4419
# Epoch 1: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00001-1.32317-0.42836-2.49057-0.18000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 222s 10s/step - categorical_accuracy: 0.3696 - loss: 1.4365 - val_categorical_accuracy: 0.1800 - val_loss: 2.4906 - learning_rate: 0.0100
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.5150 - loss: 1.1670
# Epoch 2: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00002-1.09255-0.53243-1.88698-0.25000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.5158 - loss: 1.1636 - val_categorical_accuracy: 0.2500 - val_loss: 1.8870 - learning_rate: 0.0100
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.6378 - loss: 0.8883
# Epoch 3: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00003-0.90510-0.61538-2.52824-0.18000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - categorical_accuracy: 0.6367 - loss: 0.8890 - val_categorical_accuracy: 0.1800 - val_loss: 2.5282 - learning_rate: 0.0100
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7047 - loss: 0.7396
# Epoch 4: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00004-0.74576-0.69532-2.02486-0.21000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.7042 - loss: 0.7399 - val_categorical_accuracy: 0.2100 - val_loss: 2.0249 - learning_rate: 0.0100
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7291 - loss: 0.6347
# Epoch 5: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00005-0.62391-0.73906-2.29400-0.25000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.7296 - loss: 0.6343 - val_categorical_accuracy: 0.2500 - val_loss: 2.2940 - learning_rate: 0.0100
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7824 - loss: 0.5055
# Epoch 6: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00006-0.58968-0.77074-5.97482-0.24000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.7819 - loss: 0.5093 - val_categorical_accuracy: 0.2400 - val_loss: 5.9748 - learning_rate: 0.0100
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7662 - loss: 0.5471
# Epoch 7: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00007-0.50820-0.79487-2.78965-0.20000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.7675 - loss: 0.5453 - val_categorical_accuracy: 0.2000 - val_loss: 2.7896 - learning_rate: 0.0100
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8724 - loss: 0.3703
# Epoch 8: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00008-0.37443-0.86727-1.99621-0.28000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.8722 - loss: 0.3705 - val_categorical_accuracy: 0.2800 - val_loss: 1.9962 - learning_rate: 0.0020
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8657 - loss: 0.3633
# Epoch 9: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00009-0.35659-0.86878-2.16538-0.31000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.8658 - loss: 0.3630 - val_categorical_accuracy: 0.3100 - val_loss: 2.1654 - learning_rate: 0.0020
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9001 - loss: 0.3008
# Epoch 10: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00010-0.31286-0.89291-2.02551-0.26000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.8998 - loss: 0.3013 - val_categorical_accuracy: 0.2600 - val_loss: 2.0255 - learning_rate: 0.0020
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9139 - loss: 0.2932
# Epoch 11: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00011-0.27605-0.90799-2.70676-0.21000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9137 - loss: 0.2924 - val_categorical_accuracy: 0.2100 - val_loss: 2.7068 - learning_rate: 0.0020
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8914 - loss: 0.2658
# Epoch 12: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00012-0.28117-0.89744-2.89199-0.21000.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.001.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.8917 - loss: 0.2665 - val_categorical_accuracy: 0.2100 - val_loss: 2.8920 - learning_rate: 0.0020
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8829 - loss: 0.2947
# Epoch 13: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00013-0.25393-0.90649-2.57983-0.26000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.8840 - loss: 0.2929 - val_categorical_accuracy: 0.2600 - val_loss: 2.5798 - learning_rate: 0.0010
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9455 - loss: 0.1982
# Epoch 14: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00014-0.21118-0.93363-2.78917-0.26000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9449 - loss: 0.1988 - val_categorical_accuracy: 0.2600 - val_loss: 2.7892 - learning_rate: 0.0010
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9203 - loss: 0.2247
# Epoch 15: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00015-0.24077-0.91403-2.69984-0.29000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9200 - loss: 0.2254 - val_categorical_accuracy: 0.2900 - val_loss: 2.6998 - learning_rate: 0.0010
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9145 - loss: 0.2096
# Epoch 16: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00016-0.22143-0.91252-2.26000-0.33000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9144 - loss: 0.2101 - val_categorical_accuracy: 0.3300 - val_loss: 2.2600 - learning_rate: 0.0010
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8956 - loss: 0.2569
# Epoch 17: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00017-0.22445-0.91403-2.49396-0.26000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.8965 - loss: 0.2554 - val_categorical_accuracy: 0.2600 - val_loss: 2.4940 - learning_rate: 0.0010
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9142 - loss: 0.2216
# Epoch 18: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00018-0.22655-0.91554-2.03509-0.43000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9143 - loss: 0.2219 - val_categorical_accuracy: 0.4300 - val_loss: 2.0351 - learning_rate: 0.0010
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9172 - loss: 0.1976
# Epoch 19: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00019-0.21275-0.91554-1.82861-0.43000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - categorical_accuracy: 0.9171 - loss: 0.1983 - val_categorical_accuracy: 0.4300 - val_loss: 1.8286 - learning_rate: 0.0010
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9295 - loss: 0.1853
# Epoch 20: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00020-0.20345-0.92157-1.77674-0.46000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - categorical_accuracy: 0.9291 - loss: 0.1862 - val_categorical_accuracy: 0.4600 - val_loss: 1.7767 - learning_rate: 0.0010
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9211 - loss: 0.1944
# Epoch 21: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00021-0.18808-0.92760-1.61455-0.49000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9214 - loss: 0.1941 - val_categorical_accuracy: 0.4900 - val_loss: 1.6145 - learning_rate: 0.0010
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9374 - loss: 0.1689
# Epoch 22: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00022-0.19947-0.92006-1.32473-0.56000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9366 - loss: 0.1703 - val_categorical_accuracy: 0.5600 - val_loss: 1.3247 - learning_rate: 0.0010
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9515 - loss: 0.1556
# Epoch 23: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00023-0.17514-0.94118-1.19927-0.63000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9510 - loss: 0.1565 - val_categorical_accuracy: 0.6300 - val_loss: 1.1993 - learning_rate: 0.0010
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9435 - loss: 0.1612
# Epoch 24: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00024-0.16865-0.93816-1.16679-0.61000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9432 - loss: 0.1616 - val_categorical_accuracy: 0.6100 - val_loss: 1.1668 - learning_rate: 0.0010
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9340 - loss: 0.1811
# Epoch 25: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00025-0.17572-0.93213-0.77517-0.73000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9339 - loss: 0.1808 - val_categorical_accuracy: 0.7300 - val_loss: 0.7752 - learning_rate: 0.0010
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9414 - loss: 0.1602
# Epoch 26: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00026-0.14527-0.95023-0.65075-0.81000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9418 - loss: 0.1595 - val_categorical_accuracy: 0.8100 - val_loss: 0.6507 - learning_rate: 0.0010
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9202 - loss: 0.1883
# Epoch 27: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00027-0.17838-0.92609-0.58964-0.78000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9205 - loss: 0.1878 - val_categorical_accuracy: 0.7800 - val_loss: 0.5896 - learning_rate: 0.0010
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9332 - loss: 0.1762
# Epoch 28: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00028-0.15567-0.93816-0.58798-0.84000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9335 - loss: 0.1752 - val_categorical_accuracy: 0.8400 - val_loss: 0.5880 - learning_rate: 0.0010
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9474 - loss: 0.1499
# Epoch 29: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00029-0.16987-0.94118-0.49077-0.87000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9471 - loss: 0.1508 - val_categorical_accuracy: 0.8700 - val_loss: 0.4908 - learning_rate: 0.0010
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9344 - loss: 0.1718
# Epoch 30: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00030-0.16645-0.94268-0.45915-0.84000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9348 - loss: 0.1715 - val_categorical_accuracy: 0.8400 - val_loss: 0.4592 - learning_rate: 0.0010
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9569 - loss: 0.1255
# Epoch 31: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00031-0.11997-0.95928-0.32659-0.89000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9570 - loss: 0.1252 - val_categorical_accuracy: 0.8900 - val_loss: 0.3266 - learning_rate: 0.0010
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9257 - loss: 0.1770
# Epoch 32: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00032-0.16780-0.92459-0.28714-0.90000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9257 - loss: 0.1766 - val_categorical_accuracy: 0.9000 - val_loss: 0.2871 - learning_rate: 0.0010
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9247 - loss: 0.1999
# Epoch 33: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00033-0.15018-0.95023-0.41239-0.88000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9258 - loss: 0.1976 - val_categorical_accuracy: 0.8800 - val_loss: 0.4124 - learning_rate: 0.0010
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9296 - loss: 0.1620
# Epoch 34: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00034-0.14480-0.94118-0.40670-0.88000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9302 - loss: 0.1612 - val_categorical_accuracy: 0.8800 - val_loss: 0.4067 - learning_rate: 0.0010
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9635 - loss: 0.1158
# Epoch 35: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00035-0.11260-0.96229-0.32816-0.88000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9634 - loss: 0.1157 - val_categorical_accuracy: 0.8800 - val_loss: 0.3282 - learning_rate: 0.0010
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9697 - loss: 0.1250
# Epoch 36: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00036-0.12111-0.96682-0.39625-0.85000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9696 - loss: 0.1248 - val_categorical_accuracy: 0.8500 - val_loss: 0.3962 - learning_rate: 0.0010
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9479 - loss: 0.1270
# Epoch 37: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00037-0.11388-0.95626-0.39490-0.87000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9482 - loss: 0.1264 - val_categorical_accuracy: 0.8700 - val_loss: 0.3949 - learning_rate: 0.0010
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9443 - loss: 0.1421
# Epoch 38: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00038-0.14188-0.94721-0.35516-0.88000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9444 - loss: 0.1421 - val_categorical_accuracy: 0.8800 - val_loss: 0.3552 - learning_rate: 0.0010
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9826 - loss: 0.0866
# Epoch 39: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00039-0.11028-0.96983-0.28150-0.89000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9820 - loss: 0.0877 - val_categorical_accuracy: 0.8900 - val_loss: 0.2815 - learning_rate: 0.0010
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9474 - loss: 0.1315
# Epoch 40: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00040-0.13223-0.94268-0.32242-0.91000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9472 - loss: 0.1315 - val_categorical_accuracy: 0.9100 - val_loss: 0.3224 - learning_rate: 0.0010
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9497 - loss: 0.1304
# Epoch 41: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00041-0.12622-0.95626-0.27038-0.92000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9500 - loss: 0.1302 - val_categorical_accuracy: 0.9200 - val_loss: 0.2704 - learning_rate: 0.0010
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9583 - loss: 0.1113
# Epoch 42: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00042-0.11034-0.96078-0.42788-0.87000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9584 - loss: 0.1113 - val_categorical_accuracy: 0.8700 - val_loss: 0.4279 - learning_rate: 0.0010
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9587 - loss: 0.1041
# Epoch 43: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00043-0.10588-0.95626-0.28435-0.89000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9586 - loss: 0.1042 - val_categorical_accuracy: 0.8900 - val_loss: 0.2844 - learning_rate: 0.0010
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9780 - loss: 0.0849
# Epoch 44: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00044-0.08985-0.97285-0.41393-0.89000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9778 - loss: 0.0851 - val_categorical_accuracy: 0.8900 - val_loss: 0.4139 - learning_rate: 0.0010
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9712 - loss: 0.0949
# Epoch 45: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00045-0.10092-0.96983-0.37500-0.88000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9712 - loss: 0.0952 - val_categorical_accuracy: 0.8800 - val_loss: 0.3750 - learning_rate: 0.0010
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9567 - loss: 0.1147
# Epoch 46: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00046-0.13121-0.95173-0.43438-0.85000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - categorical_accuracy: 0.9565 - loss: 0.1154 - val_categorical_accuracy: 0.8500 - val_loss: 0.4344 - learning_rate: 0.0010
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9796 - loss: 0.0814
# Epoch 47: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00047-0.11044-0.96380-0.30244-0.90000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9788 - loss: 0.0827 - val_categorical_accuracy: 0.9000 - val_loss: 0.3024 - learning_rate: 0.0010
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9783 - loss: 0.0711
# Epoch 48: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00048-0.08749-0.97285-0.22007-0.92000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9781 - loss: 0.0718 - val_categorical_accuracy: 0.9200 - val_loss: 0.2201 - learning_rate: 0.0010
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9687 - loss: 0.0896
# Epoch 49: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00049-0.10665-0.95475-0.27615-0.90000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9680 - loss: 0.0903 - val_categorical_accuracy: 0.9000 - val_loss: 0.2761 - learning_rate: 0.0010
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9856 - loss: 0.0608
# Epoch 50: saving model to model_new_generator1_2024-04-3016_54_25.765866/model-00050-0.08093-0.97587-0.34355-0.90000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - categorical_accuracy: 0.9852 - loss: 0.0618 - val_categorical_accuracy: 0.9000 - val_loss: 0.3436 - learning_rate: 0.0010

# %%
import pandas as pd
# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)
# save to json:
hist_json_file = f'{model_name[:-1]}.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv:
# hist_csv_file = 'history.csv'
# with open(hist_csv_file, mode='w') as f:
#     hist_df.to_csv(f)

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
