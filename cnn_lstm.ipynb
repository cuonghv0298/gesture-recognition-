# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
# import
from scipy_pilutil import imread, imresize
import imageio
from skimage.transform import resize, rescale
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/train.csv').readlines())
# val_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/val.csv').readlines())
# batch_size = #experiment with the batch size

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('../Project_data/', ablation=None)
# train_doc, val_doc = get_data('/content/drive/MyDrive/gesture-recognition/Project_data/', ablation=None)

batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
image1 = imageio.imread("../Project_data/val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00015.png")
#160 by 120
image2 = imageio.imread("../Project_data/val/WIN_20180907_15_38_42_Pro_Thumbs Up_new/WIN_20180907_15_38_42_Pro_00007.png")
#crop the images and resize them. Note that the images are of 2 different shape
#and the conv3D will throw error if the inputs in a batch have different shapes
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)
plt.imshow(image2)
plt.show()
## Test code end

# %%
def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                    #batch_data[folder,idx,:,:,0] = (image[...,0] - image[...,0].min())/(image[...,0].max() - image[...,0].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,1] = (image[...,1] - image[...,1].min())/(image[...,1].max() - image[...,1].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,2] = (image[...,2] - image[...,2].min())/(image[...,2].max() - image[...,2].min())#normalise and feed in the image

                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
# train_path = '../Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
# val_path =  '../Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'
train_path = '../Project_data/train'
val_path =  '../Project_data/val'
#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers


#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %% [markdown]
# ## TimeDistributed and ConvLSTM2D

# %%
def TD_ConLSTM(input_shape):
    model = Sequential()
    model.add(TimeDistributed(
        Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
    )
    model.add(BatchNormalization())
    model.add(TimeDistributed(
        Conv2D(16, (3,3), activation='relu'))
    )
    model.add(BatchNormalization())
    model.add(
        ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
    )
    model.add(BatchNormalization())
    model.add(TimeDistributed(
        Dense(64, activation='relu'))
    )
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling2D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(5, activation='softmax'))
    return model
# model = TD_ConLSTM(input_shape = input_shape )

# %% [markdown]
# ## CNN LSTM

# %%
def CNN_LSTM(lstm_cells=64,dense_neurons=64,dropout=0.25, input_shape = ()):
    model = Sequential()

    model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                input_shape=input_shape))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(lstm_cells))
    model.add(Dropout(dropout))
    
    model.add(Dense(dense_neurons,activation='relu'))
    model.add(Dropout(dropout))
    
    model.add(Dense(5, activation='softmax'))
    return model

model = CNN_LSTM(input_shape = input_shape)

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generate(train_path, train_doc, batch_size)
val_generator = generate(val_path, val_doc, batch_size)

# %%
optimiser = optimizers.Adam(learning_rate=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 10, 120, 120,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 10, 120, 120,   │            64 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 10, 60, 60, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 10, 60, 60, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 10, 60, 60, 32) │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 10, 30, 30, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_6              │ (None, 10, 30, 30, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 10, 30, 30, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 10, 15, 15, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 10, 15, 15,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 10, 15, 15,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_11             │ (None, 10, 7, 7, 128)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_12             │ (None, 10, 7, 7, 256)  │       295,168 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_13             │ (None, 10, 7, 7, 256)  │         1,024 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_14             │ (None, 10, 3, 3, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_15             │ (None, 10, 2304)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │       606,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,005,541 (3.84 MB)
#  Trainable params: 1,004,549 (3.83 MB)
#  Non-trainable params: 992 (3.88 KB)
# None

# %%
model_name = 'model_cnn_lstm' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_weights_only=False, save_best_only=False, mode='max')
LR =ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps =validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21s/step - categorical_accuracy: 0.2585 - loss: 1.5840
# Epoch 1: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00001-1.55376-0.29713-1.42980-0.40000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 495s 22s/step - categorical_accuracy: 0.2602 - loss: 1.5826 - val_categorical_accuracy: 0.4000 - val_loss: 1.4298 - learning_rate: 0.0100
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - categorical_accuracy: 0.3869 - loss: 1.4326
# Epoch 2: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00002-1.39220-0.41780-1.25298-0.46000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 574s 27s/step - categorical_accuracy: 0.3883 - loss: 1.4307 - val_categorical_accuracy: 0.4600 - val_loss: 1.2530 - learning_rate: 0.0100
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - categorical_accuracy: 0.4919 - loss: 1.1859
# Epoch 3: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00003-1.18481-0.48567-1.13597-0.51000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 578s 28s/step - categorical_accuracy: 0.4917 - loss: 1.1859 - val_categorical_accuracy: 0.5100 - val_loss: 1.1360 - learning_rate: 0.0100
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.4852 - loss: 1.1657
# Epoch 4: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00004-1.14825-0.48567-1.09858-0.58000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 623s 30s/step - categorical_accuracy: 0.4852 - loss: 1.1649 - val_categorical_accuracy: 0.5800 - val_loss: 1.0986 - learning_rate: 0.0100
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - categorical_accuracy: 0.5316 - loss: 1.1118
# Epoch 5: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00005-1.10175-0.53544-3.29495-0.28000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 564s 27s/step - categorical_accuracy: 0.5317 - loss: 1.1113 - val_categorical_accuracy: 0.2800 - val_loss: 3.2950 - learning_rate: 0.0100
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.5225 - loss: 1.1872
# Epoch 6: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00006-1.22023-0.50980-1.59861-0.35000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 616s 30s/step - categorical_accuracy: 0.5220 - loss: 1.1887 - val_categorical_accuracy: 0.3500 - val_loss: 1.5986 - learning_rate: 0.0100
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - categorical_accuracy: 0.4959 - loss: 1.2065
# Epoch 7: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00007-1.19826-0.49774-1.22699-0.50000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 672s 33s/step - categorical_accuracy: 0.4959 - loss: 1.2061 - val_categorical_accuracy: 0.5000 - val_loss: 1.2270 - learning_rate: 0.0100
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - categorical_accuracy: 0.5299 - loss: 1.0511
# Epoch 8: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00008-1.09514-0.52489-1.06717-0.58000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 540s 26s/step - categorical_accuracy: 0.5296 - loss: 1.0531 - val_categorical_accuracy: 0.5800 - val_loss: 1.0672 - learning_rate: 0.0100
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - categorical_accuracy: 0.5165 - loss: 1.1092
# Epoch 9: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00009-1.14173-0.49623-1.11689-0.53000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 550s 26s/step - categorical_accuracy: 0.5156 - loss: 1.1106 - val_categorical_accuracy: 0.5300 - val_loss: 1.1169 - learning_rate: 0.0100
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - categorical_accuracy: 0.5048 - loss: 1.1362
# Epoch 10: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00010-1.14241-0.48567-1.33912-0.41000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 690s 33s/step - categorical_accuracy: 0.5039 - loss: 1.1365 - val_categorical_accuracy: 0.4100 - val_loss: 1.3391 - learning_rate: 0.0100
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.5201 - loss: 1.0845
# Epoch 11: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00011-1.08953-0.52036-1.22751-0.48000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 644s 31s/step - categorical_accuracy: 0.5201 - loss: 1.0848 - val_categorical_accuracy: 0.4800 - val_loss: 1.2275 - learning_rate: 0.0100
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.4992 - loss: 1.1081
# Epoch 12: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00012-1.12572-0.47964-1.26381-0.48000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 649s 31s/step - categorical_accuracy: 0.4984 - loss: 1.1089 - val_categorical_accuracy: 0.4800 - val_loss: 1.2638 - learning_rate: 0.0100
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - categorical_accuracy: 0.5138 - loss: 1.0745
# Epoch 13: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00013-1.08111-0.51885-1.03106-0.53000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 588s 28s/step - categorical_accuracy: 0.5140 - loss: 1.0748 - val_categorical_accuracy: 0.5300 - val_loss: 1.0311 - learning_rate: 0.0100
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.5792 - loss: 1.0287
# Epoch 14: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00014-1.09624-0.55807-1.72705-0.41000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 628s 30s/step - categorical_accuracy: 0.5782 - loss: 1.0318 - val_categorical_accuracy: 0.4100 - val_loss: 1.7270 - learning_rate: 0.0100
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.4532 - loss: 1.3572
# Epoch 15: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00015-1.26227-0.47964-1.04939-0.59000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 642s 30s/step - categorical_accuracy: 0.4544 - loss: 1.3529 - val_categorical_accuracy: 0.5900 - val_loss: 1.0494 - learning_rate: 0.0100
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - categorical_accuracy: 0.6118 - loss: 1.0113
# Epoch 16: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00016-1.03666-0.58673-1.40153-0.44000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 601s 29s/step - categorical_accuracy: 0.6106 - loss: 1.0125 - val_categorical_accuracy: 0.4400 - val_loss: 1.4015 - learning_rate: 0.0100
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 36s/step - categorical_accuracy: 0.5592 - loss: 0.9806
# Epoch 17: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00017-1.01545-0.55053-1.11246-0.54000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 759s 36s/step - categorical_accuracy: 0.5588 - loss: 0.9822 - val_categorical_accuracy: 0.5400 - val_loss: 1.1125 - learning_rate: 0.0100
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - categorical_accuracy: 0.5639 - loss: 1.0354
# Epoch 18: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00018-1.03883-0.57315-0.98490-0.56000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 545s 26s/step - categorical_accuracy: 0.5643 - loss: 1.0356 - val_categorical_accuracy: 0.5600 - val_loss: 0.9849 - learning_rate: 0.0100
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - categorical_accuracy: 0.5955 - loss: 0.9996
# Epoch 19: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00019-0.99294-0.59879-1.81843-0.42000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 699s 34s/step - categorical_accuracy: 0.5957 - loss: 0.9993 - val_categorical_accuracy: 0.4200 - val_loss: 1.8184 - learning_rate: 0.0100
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - categorical_accuracy: 0.5712 - loss: 1.0284
# Epoch 20: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00020-1.01390-0.57014-0.94776-0.61000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 716s 33s/step - categorical_accuracy: 0.5711 - loss: 1.0277 - val_categorical_accuracy: 0.6100 - val_loss: 0.9478 - learning_rate: 0.0100
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.5648 - loss: 1.0260
# Epoch 21: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00021-1.06525-0.56712-1.17148-0.51000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 662s 32s/step - categorical_accuracy: 0.5649 - loss: 1.0278 - val_categorical_accuracy: 0.5100 - val_loss: 1.1715 - learning_rate: 0.0100
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - categorical_accuracy: 0.5555 - loss: 1.0554
# Epoch 22: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00022-1.13404-0.52338-1.02959-0.58000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 512s 25s/step - categorical_accuracy: 0.5541 - loss: 1.0590 - val_categorical_accuracy: 0.5800 - val_loss: 1.0296 - learning_rate: 0.0100
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.5352 - loss: 1.0456
# Epoch 23: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00023-1.03771-0.55204-0.96894-0.60000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 646s 29s/step - categorical_accuracy: 0.5360 - loss: 1.0452 - val_categorical_accuracy: 0.6000 - val_loss: 0.9689 - learning_rate: 0.0100
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - categorical_accuracy: 0.5710 - loss: 1.0610
# Epoch 24: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00024-1.05239-0.55656-1.00232-0.61000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 605s 29s/step - categorical_accuracy: 0.5703 - loss: 1.0606 - val_categorical_accuracy: 0.6100 - val_loss: 1.0023 - learning_rate: 0.0100
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.5803 - loss: 0.9793
# Epoch 25: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00025-0.98761-0.58522-0.99905-0.59000.keras
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 638s 31s/step - categorical_accuracy: 0.5805 - loss: 0.9797 - val_categorical_accuracy: 0.5900 - val_loss: 0.9990 - learning_rate: 0.0100
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - categorical_accuracy: 0.5768 - loss: 0.9869
# Epoch 26: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00026-0.95144-0.58371-0.91746-0.60000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 591s 28s/step - categorical_accuracy: 0.5771 - loss: 0.9853 - val_categorical_accuracy: 0.6000 - val_loss: 0.9175 - learning_rate: 0.0020
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.6004 - loss: 0.9406
# Epoch 27: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00027-0.92432-0.60483-0.91898-0.61000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 630s 30s/step - categorical_accuracy: 0.6006 - loss: 0.9398 - val_categorical_accuracy: 0.6100 - val_loss: 0.9190 - learning_rate: 0.0020
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.6386 - loss: 0.8798
# Epoch 28: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00028-0.89526-0.61991-0.92926-0.65000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 617s 29s/step - categorical_accuracy: 0.6378 - loss: 0.8805 - val_categorical_accuracy: 0.6500 - val_loss: 0.9293 - learning_rate: 0.0020
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.6559 - loss: 0.8508
# Epoch 29: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00029-0.87222-0.66968-0.85706-0.68000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 625s 30s/step - categorical_accuracy: 0.6565 - loss: 0.8517 - val_categorical_accuracy: 0.6800 - val_loss: 0.8571 - learning_rate: 0.0020
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - categorical_accuracy: 0.6706 - loss: 0.8142
# Epoch 30: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00030-0.80770-0.68024-0.94377-0.63000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 549s 26s/step - categorical_accuracy: 0.6710 - loss: 0.8139 - val_categorical_accuracy: 0.6300 - val_loss: 0.9438 - learning_rate: 0.0020
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.6440 - loss: 0.8084
# Epoch 31: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00031-0.80865-0.65158-0.88785-0.66000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 644s 31s/step - categorical_accuracy: 0.6444 - loss: 0.8084 - val_categorical_accuracy: 0.6600 - val_loss: 0.8878 - learning_rate: 0.0020
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - categorical_accuracy: 0.6781 - loss: 0.8113
# Epoch 32: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00032-0.81755-0.66063-0.89955-0.65000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 699s 34s/step - categorical_accuracy: 0.6773 - loss: 0.8116 - val_categorical_accuracy: 0.6500 - val_loss: 0.8995 - learning_rate: 0.0020
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.6590 - loss: 0.8745
# Epoch 33: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00033-0.81495-0.65913-0.90349-0.66000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 616s 30s/step - categorical_accuracy: 0.6590 - loss: 0.8718 - val_categorical_accuracy: 0.6600 - val_loss: 0.9035 - learning_rate: 0.0020
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - categorical_accuracy: 0.6833 - loss: 0.8105
# Epoch 34: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00034-0.82047-0.67119-0.84307-0.68000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 707s 34s/step - categorical_accuracy: 0.6828 - loss: 0.8109 - val_categorical_accuracy: 0.6800 - val_loss: 0.8431 - learning_rate: 0.0020
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.6774 - loss: 0.7834
# Epoch 35: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00035-0.75867-0.69834-0.89148-0.65000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 653s 31s/step - categorical_accuracy: 0.6783 - loss: 0.7823 - val_categorical_accuracy: 0.6500 - val_loss: 0.8915 - learning_rate: 0.0020
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.6777 - loss: 0.7779
# Epoch 36: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00036-0.78188-0.67873-0.87802-0.67000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 613s 29s/step - categorical_accuracy: 0.6778 - loss: 0.7781 - val_categorical_accuracy: 0.6700 - val_loss: 0.8780 - learning_rate: 0.0020
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - categorical_accuracy: 0.7059 - loss: 0.7019
# Epoch 37: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00037-0.71482-0.69382-0.97096-0.65000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 583s 28s/step - categorical_accuracy: 0.7053 - loss: 0.7025 - val_categorical_accuracy: 0.6500 - val_loss: 0.9710 - learning_rate: 0.0020
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.6955 - loss: 0.7370
# Epoch 38: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00038-0.77832-0.68929-0.82762-0.71000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 650s 31s/step - categorical_accuracy: 0.6952 - loss: 0.7388 - val_categorical_accuracy: 0.7100 - val_loss: 0.8276 - learning_rate: 0.0020
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.7302 - loss: 0.6858
# Epoch 39: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00039-0.71017-0.72700-0.79448-0.69000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 660s 31s/step - categorical_accuracy: 0.7301 - loss: 0.6869 - val_categorical_accuracy: 0.6900 - val_loss: 0.7945 - learning_rate: 0.0020
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.7367 - loss: 0.6777
# Epoch 40: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00040-0.70144-0.72549-0.79771-0.69000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 610s 29s/step - categorical_accuracy: 0.7362 - loss: 0.6788 - val_categorical_accuracy: 0.6900 - val_loss: 0.7977 - learning_rate: 0.0020
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - categorical_accuracy: 0.7542 - loss: 0.6656
# Epoch 41: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00041-0.69682-0.72700-0.86638-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 548s 26s/step - categorical_accuracy: 0.7530 - loss: 0.6670 - val_categorical_accuracy: 0.7500 - val_loss: 0.8664 - learning_rate: 0.0020
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.7030 - loss: 0.7657
# Epoch 42: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00042-0.68519-0.73906-0.82875-0.71000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 637s 31s/step - categorical_accuracy: 0.7046 - loss: 0.7620 - val_categorical_accuracy: 0.7100 - val_loss: 0.8287 - learning_rate: 0.0020
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - categorical_accuracy: 0.7390 - loss: 0.6357
# Epoch 43: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00043-0.65498-0.73152-0.78087-0.70000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 567s 27s/step - categorical_accuracy: 0.7386 - loss: 0.6366 - val_categorical_accuracy: 0.7000 - val_loss: 0.7809 - learning_rate: 0.0020
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - categorical_accuracy: 0.7614 - loss: 0.6391
# Epoch 44: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00044-0.64150-0.76169-0.74301-0.73000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 676s 32s/step - categorical_accuracy: 0.7614 - loss: 0.6392 - val_categorical_accuracy: 0.7300 - val_loss: 0.7430 - learning_rate: 0.0020
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 34s/step - categorical_accuracy: 0.7519 - loss: 0.6111
# Epoch 45: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00045-0.63042-0.75566-0.79832-0.73000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 731s 35s/step - categorical_accuracy: 0.7521 - loss: 0.6119 - val_categorical_accuracy: 0.7300 - val_loss: 0.7983 - learning_rate: 0.0020
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.7776 - loss: 0.5569
# Epoch 46: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00046-0.59696-0.77979-0.81204-0.70000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 635s 30s/step - categorical_accuracy: 0.7777 - loss: 0.5587 - val_categorical_accuracy: 0.7000 - val_loss: 0.8120 - learning_rate: 0.0020
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.7810 - loss: 0.5953
# Epoch 47: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00047-0.61059-0.76621-0.78164-0.71000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 656s 32s/step - categorical_accuracy: 0.7804 - loss: 0.5960 - val_categorical_accuracy: 0.7100 - val_loss: 0.7816 - learning_rate: 0.0020
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.7037 - loss: 0.7272
# Epoch 48: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00048-0.66465-0.73454-0.78700-0.74000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 642s 29s/step - categorical_accuracy: 0.7051 - loss: 0.7244 - val_categorical_accuracy: 0.7400 - val_loss: 0.7870 - learning_rate: 0.0020
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.7616 - loss: 0.6508
# Epoch 49: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00049-0.61125-0.78733-0.81439-0.76000.keras
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.001.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 640s 31s/step - categorical_accuracy: 0.7628 - loss: 0.6490 - val_categorical_accuracy: 0.7600 - val_loss: 0.8144 - learning_rate: 0.0020
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.7820 - loss: 0.5334
# Epoch 50: saving model to model_cnn_lstm_2024-04-3021_33_17.497228/model-00050-0.59186-0.76169-0.71197-0.79000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 616s 29s/step - categorical_accuracy: 0.7811 - loss: 0.5360 - val_categorical_accuracy: 0.7900 - val_loss: 0.7120 - learning_rate: 0.0010

# %%
import pandas as pd
# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)
# save to json:
hist_json_file = f'{model_name[:-1]}.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv:
# hist_csv_file = 'history.csv'
# with open(hist_csv_file, mode='w') as f:
#     hist_df.to_csv(f)

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
