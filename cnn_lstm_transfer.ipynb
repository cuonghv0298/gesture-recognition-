# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
# import
from scipy_pilutil import imread, imresize
import imageio
from skimage.transform import resize, rescale
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/train.csv').readlines())
# val_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/val.csv').readlines())
# batch_size = #experiment with the batch size

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('../Project_data/', ablation=None)
# train_doc, val_doc = get_data('/content/drive/MyDrive/gesture-recognition/Project_data/', ablation=None)

batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
image1 = imageio.imread("../Project_data/val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00015.png")
#160 by 120
image2 = imageio.imread("../Project_data/val/WIN_20180907_15_38_42_Pro_Thumbs Up_new/WIN_20180907_15_38_42_Pro_00007.png")
#crop the images and resize them. Note that the images are of 2 different shape
#and the conv3D will throw error if the inputs in a batch have different shapes
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)
plt.imshow(image2)
plt.show()
## Test code end

# %%
def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                    #batch_data[folder,idx,:,:,0] = (image[...,0] - image[...,0].min())/(image[...,0].max() - image[...,0].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,1] = (image[...,1] - image[...,1].min())/(image[...,1].max() - image[...,1].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,2] = (image[...,2] - image[...,2].min())/(image[...,2].max() - image[...,2].min())#normalise and feed in the image

                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
# train_path = '../Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
# val_path =  '../Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'
train_path = '../Project_data/train'
val_path =  '../Project_data/val'
#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers


#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %% [markdown]
# ## TimeDistributed and ConvLSTM2D

# %%
def TD_ConLSTM(input_shape):
    model = Sequential()
    model.add(TimeDistributed(
        Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
    )
    model.add(BatchNormalization())
    model.add(TimeDistributed(
        Conv2D(16, (3,3), activation='relu'))
    )
    model.add(BatchNormalization())
    model.add(
        ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
    )
    model.add(BatchNormalization())
    model.add(TimeDistributed(
        Dense(64, activation='relu'))
    )
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling2D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(5, activation='softmax'))
    return model
# model = TD_ConLSTM(input_shape = input_shape )

# %% [markdown]
# ## CNN LSTM

# %%
def CNN_LSTM(lstm_cells=64,dense_neurons=64,dropout=0.25, input_shape = ()):
    model = Sequential()

    model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                input_shape=input_shape))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
    model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(lstm_cells))
    model.add(Dropout(dropout))
    
    model.add(Dense(dense_neurons,activation='relu'))
    model.add(Dropout(dropout))
    
    model.add(Dense(5, activation='softmax'))
    return model

# model = CNN_LSTM(input_shape = input_shape)

# %% [markdown]
# ## CNN LSTM with Transfer Learning

# %%
from keras.applications import mobilenet
def CNN_LSTM_TL(lstm_cells=64,dense_neurons=64,dropout=0.25, input_shape = ()):            
    mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
    model = Sequential()
    model.add(TimeDistributed(mobilenet_transfer,input_shape=input_shape))
    
    
    for layer in model.layers:
        layer.trainable = False
    
    
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(lstm_cells))
    model.add(Dropout(dropout))
    
    model.add(Dense(dense_neurons,activation='relu'))
    model.add(Dropout(dropout))
    
    model.add(Dense(5, activation='softmax'))
    
    return model

model = CNN_LSTM_TL(input_shape = input_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generate(train_path, train_doc, batch_size)
val_generator = generate(val_path, val_doc, batch_size)

# %%
optimiser = optimizers.Adam(learning_rate=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ ?                      │     3,228,864 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,228,864 (12.32 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 3,228,864 (12.32 MB)
# None

# %%
model_name = 'model_cnn_lstm_tl' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_weights_only=False, save_best_only=False, mode='max')
LR =ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps =validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.3556 - loss: 1.4864
# Epoch 1: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00001-1.34124-0.44344-0.90839-0.68000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 136s 5s/step - categorical_accuracy: 0.3596 - loss: 1.4798 - val_categorical_accuracy: 0.6800 - val_loss: 0.9084 - learning_rate: 0.0100
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.6801 - loss: 0.8446
# Epoch 2: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00002-0.82808-0.69382-0.86510-0.66000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.6807 - loss: 0.8439 - val_categorical_accuracy: 0.6600 - val_loss: 0.8651 - learning_rate: 0.0100
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.7969 - loss: 0.5831
# Epoch 3: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00003-0.55807-0.79940-0.66933-0.78000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.7970 - loss: 0.5820 - val_categorical_accuracy: 0.7800 - val_loss: 0.6693 - learning_rate: 0.0100
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.8655 - loss: 0.3616
# Epoch 4: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00004-0.35472-0.86576-0.69786-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - categorical_accuracy: 0.8655 - loss: 0.3613 - val_categorical_accuracy: 0.7500 - val_loss: 0.6979 - learning_rate: 0.0100
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.8992 - loss: 0.3069
# Epoch 5: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00005-0.31572-0.88386-0.63208-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.8985 - loss: 0.3073 - val_categorical_accuracy: 0.7700 - val_loss: 0.6321 - learning_rate: 0.0100
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.8737 - loss: 0.3565
# Epoch 6: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00006-0.35406-0.87934-0.70529-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - categorical_accuracy: 0.8739 - loss: 0.3564 - val_categorical_accuracy: 0.7700 - val_loss: 0.7053 - learning_rate: 0.0100
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9122 - loss: 0.2647
# Epoch 7: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00007-0.27626-0.90950-0.64358-0.79000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - categorical_accuracy: 0.9121 - loss: 0.2653 - val_categorical_accuracy: 0.7900 - val_loss: 0.6436 - learning_rate: 0.0100
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9482 - loss: 0.1516
# Epoch 8: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00008-0.17020-0.93665-0.76361-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 93s 4s/step - categorical_accuracy: 0.9477 - loss: 0.1524 - val_categorical_accuracy: 0.7700 - val_loss: 0.7636 - learning_rate: 0.0100
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9331 - loss: 0.1827
# Epoch 9: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00009-0.20048-0.92609-0.74070-0.74000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9328 - loss: 0.1835 - val_categorical_accuracy: 0.7400 - val_loss: 0.7407 - learning_rate: 0.0100
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9394 - loss: 0.1622
# Epoch 10: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00010-0.17977-0.94118-0.74569-0.74000.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9395 - loss: 0.1630 - val_categorical_accuracy: 0.7400 - val_loss: 0.7457 - learning_rate: 0.0100
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9641 - loss: 0.0946
# Epoch 11: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00011-0.10934-0.96380-0.74382-0.76000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9641 - loss: 0.0952 - val_categorical_accuracy: 0.7600 - val_loss: 0.7438 - learning_rate: 0.0020
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9500 - loss: 0.1170
# Epoch 12: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00012-0.10567-0.95777-0.73667-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9503 - loss: 0.1165 - val_categorical_accuracy: 0.7700 - val_loss: 0.7367 - learning_rate: 0.0020
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9781 - loss: 0.0976
# Epoch 13: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00013-0.08160-0.97738-0.78779-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - categorical_accuracy: 0.9781 - loss: 0.0969 - val_categorical_accuracy: 0.7700 - val_loss: 0.7878 - learning_rate: 0.0020
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9791 - loss: 0.0704
# Epoch 14: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00014-0.06792-0.98039-0.79749-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - categorical_accuracy: 0.9792 - loss: 0.0703 - val_categorical_accuracy: 0.7700 - val_loss: 0.7975 - learning_rate: 0.0020
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9818 - loss: 0.0538
# Epoch 15: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00015-0.05756-0.97436-0.75827-0.78000.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.001.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9815 - loss: 0.0540 - val_categorical_accuracy: 0.7800 - val_loss: 0.7583 - learning_rate: 0.0020
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9702 - loss: 0.0767
# Epoch 16: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00016-0.07330-0.97134-0.76329-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9702 - loss: 0.0765 - val_categorical_accuracy: 0.7500 - val_loss: 0.7633 - learning_rate: 0.0010
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9903 - loss: 0.0513
# Epoch 17: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00017-0.05758-0.98492-0.78391-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9900 - loss: 0.0516 - val_categorical_accuracy: 0.7500 - val_loss: 0.7839 - learning_rate: 0.0010
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9893 - loss: 0.0345
# Epoch 18: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00018-0.03305-0.98944-0.77494-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9893 - loss: 0.0345 - val_categorical_accuracy: 0.7700 - val_loss: 0.7749 - learning_rate: 0.0010
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9943 - loss: 0.0311
# Epoch 19: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00019-0.03812-0.99246-0.77860-0.78000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9942 - loss: 0.0314 - val_categorical_accuracy: 0.7800 - val_loss: 0.7786 - learning_rate: 0.0010
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9856 - loss: 0.0377
# Epoch 20: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00020-0.03610-0.98944-0.76198-0.78000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 92s 4s/step - categorical_accuracy: 0.9858 - loss: 0.0376 - val_categorical_accuracy: 0.7800 - val_loss: 0.7620 - learning_rate: 0.0010
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9949 - loss: 0.0236
# Epoch 21: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00021-0.02998-0.98944-0.77287-0.79000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - categorical_accuracy: 0.9947 - loss: 0.0239 - val_categorical_accuracy: 0.7900 - val_loss: 0.7729 - learning_rate: 0.0010
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9899 - loss: 0.0338
# Epoch 22: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00022-0.03634-0.98793-0.77153-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9899 - loss: 0.0339 - val_categorical_accuracy: 0.7700 - val_loss: 0.7715 - learning_rate: 0.0010
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9858 - loss: 0.0433
# Epoch 23: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00023-0.04385-0.98492-0.84931-0.76000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9858 - loss: 0.0433 - val_categorical_accuracy: 0.7600 - val_loss: 0.8493 - learning_rate: 0.0010
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9938 - loss: 0.0284
# Epoch 24: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00024-0.03328-0.99095-0.79424-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9937 - loss: 0.0286 - val_categorical_accuracy: 0.7700 - val_loss: 0.7942 - learning_rate: 0.0010
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9881 - loss: 0.0378
# Epoch 25: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00025-0.02968-0.99246-0.83141-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9883 - loss: 0.0374 - val_categorical_accuracy: 0.7700 - val_loss: 0.8314 - learning_rate: 0.0010
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9785 - loss: 0.0456
# Epoch 26: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00026-0.03908-0.98643-0.81794-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9788 - loss: 0.0453 - val_categorical_accuracy: 0.7700 - val_loss: 0.8179 - learning_rate: 0.0010
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9930 - loss: 0.0289
# Epoch 27: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00027-0.03803-0.98944-0.81794-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9928 - loss: 0.0293 - val_categorical_accuracy: 0.7700 - val_loss: 0.8179 - learning_rate: 0.0010
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9930 - loss: 0.0347
# Epoch 28: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00028-0.03692-0.99095-0.83927-0.78000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9929 - loss: 0.0348 - val_categorical_accuracy: 0.7800 - val_loss: 0.8393 - learning_rate: 0.0010
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9851 - loss: 0.0392
# Epoch 29: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00029-0.03775-0.98643-0.79173-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9852 - loss: 0.0391 - val_categorical_accuracy: 0.7700 - val_loss: 0.7917 - learning_rate: 0.0010
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9907 - loss: 0.0338
# Epoch 30: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00030-0.02521-0.99397-0.82102-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9909 - loss: 0.0334 - val_categorical_accuracy: 0.7700 - val_loss: 0.8210 - learning_rate: 0.0010
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9892 - loss: 0.0237
# Epoch 31: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00031-0.02700-0.98944-0.80766-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9892 - loss: 0.0239 - val_categorical_accuracy: 0.7700 - val_loss: 0.8077 - learning_rate: 0.0010
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9895 - loss: 0.0370
# Epoch 32: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00032-0.03557-0.98793-0.84793-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9894 - loss: 0.0370 - val_categorical_accuracy: 0.7500 - val_loss: 0.8479 - learning_rate: 0.0010
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9964 - loss: 0.0213
# Epoch 33: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00033-0.02469-0.99397-0.81905-0.78000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9963 - loss: 0.0215 - val_categorical_accuracy: 0.7800 - val_loss: 0.8190 - learning_rate: 0.0010
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 1.0000 - loss: 0.0123
# Epoch 34: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00034-0.01173-1.00000-0.83041-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 1.0000 - loss: 0.0123 - val_categorical_accuracy: 0.7500 - val_loss: 0.8304 - learning_rate: 0.0010
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9934 - loss: 0.0248
# Epoch 35: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00035-0.02653-0.99095-0.79991-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9933 - loss: 0.0249 - val_categorical_accuracy: 0.7700 - val_loss: 0.7999 - learning_rate: 0.0010
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9968 - loss: 0.0165
# Epoch 36: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00036-0.01550-0.99849-0.84991-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9969 - loss: 0.0164 - val_categorical_accuracy: 0.7700 - val_loss: 0.8499 - learning_rate: 0.0010
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9923 - loss: 0.0213
# Epoch 37: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00037-0.02262-0.99095-0.91634-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9922 - loss: 0.0214 - val_categorical_accuracy: 0.7500 - val_loss: 0.9163 - learning_rate: 0.0010
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9986 - loss: 0.0096
# Epoch 38: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00038-0.01228-0.99849-0.87115-0.78000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9986 - loss: 0.0097 - val_categorical_accuracy: 0.7800 - val_loss: 0.8711 - learning_rate: 0.0010
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9999 - loss: 0.0118
# Epoch 39: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00039-0.01524-0.99849-0.97575-0.73000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9998 - loss: 0.0120 - val_categorical_accuracy: 0.7300 - val_loss: 0.9758 - learning_rate: 0.0010
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9919 - loss: 0.0242
# Epoch 40: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00040-0.02206-0.99246-0.87524-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9919 - loss: 0.0241 - val_categorical_accuracy: 0.7700 - val_loss: 0.8752 - learning_rate: 0.0010
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9992 - loss: 0.0099
# Epoch 41: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00041-0.01105-0.99698-0.88033-0.77000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9991 - loss: 0.0099 - val_categorical_accuracy: 0.7700 - val_loss: 0.8803 - learning_rate: 0.0010
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9978 - loss: 0.0134
# Epoch 42: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00042-0.01512-0.99698-0.91003-0.74000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9978 - loss: 0.0135 - val_categorical_accuracy: 0.7400 - val_loss: 0.9100 - learning_rate: 0.0010
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9937 - loss: 0.0204
# Epoch 43: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00043-0.02042-0.99397-0.92369-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9937 - loss: 0.0204 - val_categorical_accuracy: 0.7500 - val_loss: 0.9237 - learning_rate: 0.0010
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9855 - loss: 0.0316
# Epoch 44: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00044-0.03095-0.99095-0.92696-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9858 - loss: 0.0315 - val_categorical_accuracy: 0.7500 - val_loss: 0.9270 - learning_rate: 0.0010
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9979 - loss: 0.0149
# Epoch 45: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00045-0.01602-0.99698-0.91130-0.76000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9979 - loss: 0.0149 - val_categorical_accuracy: 0.7600 - val_loss: 0.9113 - learning_rate: 0.0010
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9909 - loss: 0.0270
# Epoch 46: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00046-0.02572-0.99246-0.87460-0.80000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9910 - loss: 0.0269 - val_categorical_accuracy: 0.8000 - val_loss: 0.8746 - learning_rate: 0.0010
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9914 - loss: 0.0299
# Epoch 47: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00047-0.02310-0.99246-0.92548-0.76000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - categorical_accuracy: 0.9914 - loss: 0.0296 - val_categorical_accuracy: 0.7600 - val_loss: 0.9255 - learning_rate: 0.0010
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9950 - loss: 0.0191
# Epoch 48: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00048-0.02044-0.99246-0.95028-0.74000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9949 - loss: 0.0191 - val_categorical_accuracy: 0.7400 - val_loss: 0.9503 - learning_rate: 0.0010
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9991 - loss: 0.0119
# Epoch 49: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00049-0.01159-0.99849-0.95857-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9990 - loss: 0.0119 - val_categorical_accuracy: 0.7500 - val_loss: 0.9586 - learning_rate: 0.0010
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.9967 - loss: 0.0143
# Epoch 50: saving model to model_cnn_lstm_tl_2024-05-0109_12_09.515056/model-00050-0.01249-0.99698-0.96513-0.74000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 90s 4s/step - categorical_accuracy: 0.9967 - loss: 0.0143 - val_categorical_accuracy: 0.7400 - val_loss: 0.9651 - learning_rate: 0.0010

# %%
import pandas as pd
# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)
# save to json:
hist_json_file = f'{model_name[:-1]}.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv:
# hist_csv_file = 'history.csv'
# with open(hist_csv_file, mode='w') as f:
#     hist_df.to_csv(f)

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
